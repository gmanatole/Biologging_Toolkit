# %%
import sys, os
import pandas as pd
sys.path.append('../src/')
from Biologging_Toolkit.applications.Trajectory import Trajectory
# Out:
# c:\Users\barsro\Documents\SES_tags\notebooks\../src\Biologging_Toolkit

# %%
depid, path = "ml17_280a", "E:/individus_filtered/"
traj = Trajectory(depid, path)
traj.plot_dive(161)
# traj.save_gif_frames(dive=11)

# %%
traj.plot3D_go(dive=161)
# Out:
# c:\Users\barsro\.conda\envs\rain\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
